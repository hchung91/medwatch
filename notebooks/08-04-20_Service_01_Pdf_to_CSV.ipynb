# %%
# %load_ext autoreload
# %autoreload 2

import csv

# In order to use tabula, full Java JDK must be installed
# Academic link to download
# https://enos.itcollege.ee/~jpoial/allalaadimised/jdk13/
import tabula

# Be sure to have ghostscript installed for camelot
# On mac:
#   brew install ghostscript
import camelot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-758ff080fda9> in <module>
#      14 import camelot
#      15
# ---> 16 from pdftables.pdf_document import PDFDocument
#      17 from pdftables.pdftables import page_to_tables
#
# ModuleNotFoundError: No module named 'pdftables'

# %%
file = '../datasets/novel-coronavirus-landscape-covid-19_07-31-20.pdf'
#file = '../datasets/novel-coronavirus-landscape-covid-19-07-07-20_update.pdf'

# %%
#tables_tabula = tabula.read_pdf(file, pages = "all", multiple_tables = True)
tables_tabula = tabula.read_pdf(file, pages = "all")
print(len(tables_tabula))

# %%
tables_tabula[0]
# Out:
#                              COVID-19 Vaccine Unnamed: 0        Unnamed: 1  \
# 0                                         NaN        NaN  Vaccine platform
# 1                      developer/manufacturer        NaN               NaN
# 2                                         NaN        NaN               NaN
# 3                                         NaN        NaN               NaN
# 4                                         NaN        NaN   Non-Replicating
# 5        University of Ox  ford/A s tra Ze ne         ca               NaN
# 6                                         NaN        NaN      Viral Vector
# 7                                         NaN        NaN               NaN
# 8                                         NaN        NaN               NaN
# 9                                   Sinova  c        NaN       Inactivated
# 10                                        NaN        NaN               NaN
# ...

# %%
tables_camelot = camelot.read_pdf(file, pages= "1-end")
len(tables_camelot)
# Out:
# ...
# 0

# %%
tables_camelot[0].df
# Out:
#                                                     0  \
# 0           COVID-19 Vaccine \ndeveloper/manufacturer
# 1
# 2                    University of Oxford/AstraZeneca
# 3
# 4
# 5                                             Sinovac
# 6   Wuhan Institute of Biological \nProducts/Sinop...
# 7
# 8   Beijing Institute of Biological \nProducts/Sin...
# 9
# 10                                      Moderna/NIAID
# 11                       BioNTech/Fosun Pharma/Pfizer
# 12
# 13
# 14  CanSino Biological Inc./Beijing Institute \nof...
# 15
# 16  Anhui Zhifei Longcom \nBiopharmaceutical/Insti...
#
#                                  1  \
# 0                 Vaccine platform
# 1
# 2   Non-Replicating \nViral Vector
# 3
# 4
# 5                      Inactivated
# 6                      Inactivated
# 7
# 8                      Inactivated
# 9
# 10                             RNA
# 11                             RNA
# 12
# 13
# 14  Non-Replicating \nViral Vector
# 15
# ...
